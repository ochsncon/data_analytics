# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3464, 276)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.opening_date tags.postid tags.diet:local tags.payment:account_cards  \
# 0               NaN         NaN             NaN                        NaN
# 1               NaN         NaN             NaN                        NaN
# 2               NaN         NaN             NaN                        NaN
# 3               NaN         NaN             NaN                        NaN
# 4               NaN         NaN             NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
#   tags.recycling:low_energy_bulbs tags.opening_hours:cafe tags.name:zh-Hans
# 0                             NaN                     NaN               NaN
# 1                             NaN                     NaN               NaN
# 2                             NaN                     NaN               NaN
# 3                             NaN                     NaN               NaN
# 4                             NaN                     NaN               NaN
#
# [5 rows x 276 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ce3dd95356a30a7380851bb4928b33c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ce3dd95356a30a7380851bb4928b33c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ce3dd95356a30a7380851bb4928b33c = L.map(
#                 &quot;map_1ce3dd95356a30a7380851bb4928b33c&quot;,
#                 {
#                     center: [47.00861292186469, 8.00433809851485],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1ce3dd95356a30a7380851bb4928b33c);
#
#
#
#
#
#             var tile_layer_79baf75637856fb9e56abfd7f6a9146e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_79baf75637856fb9e56abfd7f6a9146e.addTo(map_1ce3dd95356a30a7380851bb4928b33c);
#
#
#             var marker_f0c7c8c86914c6600dbd47811ca2afe4 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_1ce3dd95356a30a7380851bb4928b33c);
#
#
#         var popup_b5aee840fe08574e1c9e7014e3a9680c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_668f73ee496593f89a4af1d268f74515 = $(`&lt;div id=&quot;html_668f73ee496593f89a4af1d268f74515&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_b5aee840fe08574e1c9e7014e3a9680c.setContent(html_668f73ee496593f89a4af1d268f74515);
#
#
#
#         marker_f0c7c8c86914c6600dbd47811ca2afe4.bindPopup(popup_b5aee840fe08574e1c9e7014e3a9680c)
#         ;
#
#
#
#
#             var marker_bea2e2d18d95b769f27ffe03eba19112 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_1ce3dd95356a30a7380851bb4928b33c);
#
#
#         var popup_6619927a3236c07a640451ff583a73c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fb21511bb7d6adc58705bda2277771c = $(`&lt;div id=&quot;html_8fb21511bb7d6adc58705bda2277771c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_6619927a3236c07a640451ff583a73c7.setContent(html_8fb21511bb7d6adc58705bda2277771c);
#
#
#
#         marker_bea2e2d18d95b769f27ffe03eba19112.bindPopup(popup_6619927a3236c07a640451ff583a73c7)
#         ;
#
#
#
#
#             var marker_3e842b17c55c4122a151b127cdd57f81 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_1ce3dd95356a30a7380851bb4928b33c);
#
#
#         var popup_d363b43da9cff2e011f1c24907e8bc04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c063557f503e43657bd79810f212bbfe = $(`&lt;div id=&quot;html_c063557f503e43657bd79810f212bbfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_d363b43da9cff2e011f1c24907e8bc04.setContent(html_c063557f503e43657bd79810f212bbfe);
#
#
#
#         marker_3e842b17c55c4122a151b127cdd57f81.bindPopup(popup_d363b43da9cff2e011f1c24907e8bc04)
#         ;
#
#
#
#
#             var marker_27b4417c9a8782ca5ea093fc6424de9e = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_1ce3dd95356a30a7380851bb4928b33c);
#
#
#         var popup_4361e2eb7e74cce41514361b349de1f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e75bdb039193518406f81f2f04ebd2a6 = $(`&lt;div id=&quot;html_e75bdb039193518406f81f2f04ebd2a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_4361e2eb7e74cce41514361b349de1f6.setContent(html_e75bdb039193518406f81f2f04ebd2a6);
#
#
#
#         marker_27b4417c9a8782ca5ea093fc6424de9e.bindPopup(popup_4361e2eb7e74cce41514361b349de1f6)
#         ;
#
#
#
#
#             var marker_1a46a9187f61ba0acd60925ffc9e4898 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_1ce3dd95356a30a7380851bb4928b33c);
#
#
#         var popup_039e9a335f5a6a38936cb97bbfd3ea8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83d0126635abbb9a0571c5a0cced3530 = $(`&lt;div id=&quot;html_83d0126635abbb9a0571c5a0cced3530&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_039e9a335f5a6a38936cb97bbfd3ea8a.setContent(html_83d0126635abbb9a0571c5a0cced3530);
#
#
#
#         marker_1a46a9187f61ba0acd60925ffc9e4898.bindPopup(popup_039e9a335f5a6a38936cb97bbfd3ea8a)
#         ;
#
#
#
#
#             var marker_fe21d9c6f09cf7fd2312fcfde052fb27 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-09-23 15:53:57
# Python Version: 3.11.13
# -----------------------------------
